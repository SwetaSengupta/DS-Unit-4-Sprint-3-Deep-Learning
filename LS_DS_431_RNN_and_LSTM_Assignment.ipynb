# %% [markdown]
# <a href="https://colab.research.google.com/github/SwetaSengupta/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/LS_DS_431_RNN_and_LSTM_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [infinite monkeys typing for an infinite amount of time](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
import requests
import pandas as pd

# %%
url = "https://www.gutenberg.org/files/100/100-0.txt"

r = requests.get(url)
r.encoding = r.apparent_encoding
data = r.text
data = data.split('\r\n')
toc = [l.strip() for l in data[44:130:2]]
# Skip the Table of Contents
data = data[135:]

# Fixing Titles
toc[9] = 'THE LIFE OF KING HENRY V'
toc[18] = 'MACBETH'
toc[24] = 'OTHELLO, THE MOOR OF VENICE'
toc[34] = 'TWELFTH NIGHT: OR, WHAT YOU WILL'

locations = {id_:{'title':title, 'start':-99} for id_,title in enumerate(toc)}

# Start 
for e,i in enumerate(data):
    for t,title in enumerate(toc):
        if title in i:
            locations[t].update({'start':e})
            

df_toc = pd.DataFrame.from_dict(locations, orient='index')
df_toc['end'] = df_toc['start'].shift(-1).apply(lambda x: x-1)
df_toc.loc[42, 'end'] = len(data)
df_toc['end'] = df_toc['end'].astype('int')

df_toc['text'] = df_toc.apply(lambda x: '\r\n'.join(data[ x['start'] : int(x['end']) ]), axis=1)

# %%
#Shakespeare Data Parsed by Play
df_toc.head()
# Out:
#                                  title  ...                                               text
# 0            ALL’S WELL THAT ENDS WELL  ...  ALL’S WELL THAT ENDS WELL\r\n\r\n\r\n\r\nConte...
# 1  THE TRAGEDY OF ANTONY AND CLEOPATRA  ...  THE TRAGEDY OF ANTONY AND CLEOPATRA\r\n\r\nDRA...
# 2                       AS YOU LIKE IT  ...  AS YOU LIKE IT\r\n\r\nDRAMATIS PERSONAE.\r\n\r...
# 3                 THE COMEDY OF ERRORS  ...  THE COMEDY OF ERRORS\r\n\r\n\r\n\r\nContents\r...
# 4            THE TRAGEDY OF CORIOLANUS  ...  THE TRAGEDY OF CORIOLANUS\r\n\r\nDramatis Pers...
#
# [5 rows x 4 columns]

# %%
# divide b/w plays and sonets
sonets = data[:2776]
plays = data[2777:]

# %%
data[0]
# Out:
# 'THE SONNETS'

# %%
def long_lines(lst_ln):
    clean = []
    
    for ln in lst_ln: 
        
        if len(ln) == 0:
            pass
        else:
            pct = len(ln.strip(' ')) / len(ln)

            if pct >= .5:
                clean.append(ln.lstrip())

    return cleand

# %% [markdown]
# ##Word Encoding

# %%
vocab = list(set("\r\n".join(plays).split()))
words = [line.split() for line in plays]

# %%
len(vocab)
# Out:
# 75738

# %%
import pandas as pd

vocab_df = pd.DataFrame(vocab, columns=["vocab"])
vocab_df.head()
# Out:
#        vocab
# 0  probable,
# 1       jade
# 2      ward.
# 3    stoutly
# 4     ‘that’

# %%
text = " ".join(vocab_df.vocab.values)

# Unique Characters
chars = list(set(text))

# Lookup Tables
char_int = {c:i for i, c in enumerate(chars)} 
int_char = {i:c for i, c in enumerate(chars)} 

print(len(chars))
# Out:
# 103

# %%
print(chars)
# Out:
# ['v', ' ', 'O', 'è', 'œ', 'y', 'U', ':', 'ê', ';', 'h', 'R', 'S', 'q', 'r', 'ç', '“', '$', 'w', 'u', 'i', '?', 'B', '"', '5', 'T', '.', 'n', 'W', 'e', 'N', 'l', 'I', '—', 'Q', 'Z', 'm', 'æ', '%', 'A', '&', 'â', '[', 'E', 'é', ')', '”', '!', '}', 'X', 'x', '*', '9', 'f', ']', 't', 's', '\\', 'É', '_', 'c', 'b', '8', 'K', 'J', 'à', '2', '3', 'p', '-', 'Æ', '(', '|', 'F', 'î', '’', '/', 'M', 'k', 'Y', '1', 'L', 'G', '@', '`', 'H', 'o', 'D', 'd', '7', 'z', "'", 'a', '‘', 'j', 'P', 'C', '0', '4', ',', 'V', '6', 'g']

# %%
vocab_df['vocab_clean'] = vocab_df['vocab'].replace({r'[^\x00-\x7F$"[]\\?@_]+':''}, regex=True, inplace=True)

# %%
text = " ".join(vocab_df.vocab.values)

# Unique Characters
chars = list(set(text))

# Lookup Tables
char_int = {c:i for i, c in enumerate(chars)} 
int_char = {i:c for i, c in enumerate(chars)} 

print(len(chars))
# Out:
# 103

# %%
print(chars)
# Out:
# ['v', ' ', 'O', 'è', 'œ', 'y', 'U', ':', 'ê', ';', 'h', 'R', 'S', 'q', 'r', 'ç', '“', '$', 'w', 'u', 'i', '?', 'B', '"', '5', 'T', '.', 'n', 'W', 'e', 'N', 'l', 'I', '—', 'Q', 'Z', 'm', 'æ', '%', 'A', '&', 'â', '[', 'E', 'é', ')', '”', '!', '}', 'X', 'x', '*', '9', 'f', ']', 't', 's', '\\', 'É', '_', 'c', 'b', '8', 'K', 'J', 'à', '2', '3', 'p', '-', 'Æ', '(', '|', 'F', 'î', '’', '/', 'M', 'k', 'Y', '1', 'L', 'G', '@', '`', 'H', 'o', 'D', 'd', '7', 'z', "'", 'a', '‘', 'j', 'P', 'C', '0', '4', ',', 'V', '6', 'g']

# %%
text = " ".join(vocab_df.vocab.values)

# Unique Characters
chars = list(set(text))

# Lookup Tables
char_int = {c:i for i, c in enumerate(chars)} 
int_char = {i:c for i, c in enumerate(chars)} 

print(len(chars))
# Out:
# 103

# %%
print(chars)
# Out:
# ['v', ' ', 'O', 'è', 'œ', 'y', 'U', ':', 'ê', ';', 'h', 'R', 'S', 'q', 'r', 'ç', '“', '$', 'w', 'u', 'i', '?', 'B', '"', '5', 'T', '.', 'n', 'W', 'e', 'N', 'l', 'I', '—', 'Q', 'Z', 'm', 'æ', '%', 'A', '&', 'â', '[', 'E', 'é', ')', '”', '!', '}', 'X', 'x', '*', '9', 'f', ']', 't', 's', '\\', 'É', '_', 'c', 'b', '8', 'K', 'J', 'à', '2', '3', 'p', '-', 'Æ', '(', '|', 'F', 'î', '’', '/', 'M', 'k', 'Y', '1', 'L', 'G', '@', '`', 'H', 'o', 'D', 'd', '7', 'z', "'", 'a', '‘', 'j', 'P', 'C', '0', '4', ',', 'V', '6', 'g']

# %% [markdown]
# ## Character Encoding

# %%
text = '\r\n'.join(sonets)

chars = list(set(text))

char_int = {c:i for i,c in enumerate(chars)}
int_char = {i:c for i,c in enumerate(chars)}

print(f"Our corpus contains {len(chars)} unique characters.")
# Out:
# Our corpus contains 73 unique characters.

# %%
# Create the Sequence Data

maxlen = 150
step = 1

encoded = [char_int[c] for c in text]

sequences = [] # Each element is 40 characters long
next_chars = [] # One element for each sequence

for i in range(0, len(encoded) - maxlen, step):
    sequences.append(encoded[i : i + maxlen])
    next_chars.append(encoded[i + maxlen])
    
print('sequences:', len(sequences))
# Out:
# sequences: 100978

# %%
import numpy as np

# Specify x & y

x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        x[i,t,char] = 1
        
    y[i, next_chars[i]] = 1

# %%
x.shape
# Out:
# (100978, 150, 73)

# %%
#imports
from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping, TensorBoard
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

import numpy as np
import random
import sys
import requests
import os
import datetime

# %%
# build the model: a single LSTM

model = Sequential()
model.add(LSTM(256, input_shape=(maxlen, len(chars)), dropout=0.2, return_sequences=True))
model.add(LSTM(256, input_shape=(maxlen, len(chars)), dropout=0.2))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='nadam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 150, 256)          337920
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dense (Dense)                (None, 73)                18761
# =================================================================
# Total params: 881,993
# Trainable params: 881,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / 1
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    
    start_index = random.randint(0, len(text) - maxlen - 1)
    
    generated = ''
    
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)
    
    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_int[char]] = 1
            
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds)
        next_char = int_char[next_index]
        
        sentence = sentence[1:] + next_char
        
        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()


print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(logdir, histogram_freq=1)

model.fit(x, y,
          batch_size=1024,
          validation_split=.2,
          epochs=100,
          callbacks=[print_callback, 
                     EarlyStopping(min_delta=.02, monitor='val_loss', patience=10),
                     tensorboard_callback])
# Out:
# Epoch 1/100
#  1/79 [..............................] - ETA: 0s - loss: 4.2921WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/79 [..............................] - ETA: 16s - loss: 4.2749WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1406s vs `on_train_batch_end` time: 0.2758s). Check your callbacks.
# 79/79 [==============================] - ETA: 0s - loss: 3.1933
# ----- Generating text after Epoch: 0
# ----- Generating with seed: "But heaven in thy creation did decree,
# That in thy face sweet love should ever dwell,
# Whate’er thy thoughts, or thy heart’s workings be,
# Thy looks "
# But heaven in thy creation did decree,
# That in thy face sweet love should ever dwell,
# Whate’er thy thoughts, or thy heart’s workings be,
# ndowhoahhohh
# eie  Wr,3i y
# nmgim t. tp waLo( t rklunglhy
#  etuor rotweecos t
#  bt    ow lest men mh eer  at,IHl
# garseso hW de
# ue, ua fynd y.
# m w  nulefea i otthac
# )i
#
#
# 79/79 [==============================] - 44s 551ms/step - loss: 3.1933 - val_loss: 3.1103
# Epoch 2/100
# 79/79 [==============================] - ETA: 0s - loss: 3.0331
# ----- Generating text after Epoch: 1
# ----- Generating with seed: "hate’s known injury.
#   Lascivious grace, in whom all ill well shows,
#   Kill me with spites yet we must not be foes.
#
#
#                     41
#
# T"
# hate’s known injury.
#   Lascivious grace, in whom all ill well shows,
#   Kill me with spites yet we must not be foes.
#
#
#                     41
#
# Te on  hualotfk  adsm-gc iedlthtWfsew.T T 4iss sset as i sb  w osnsooys.tt eo ,r pumrnbou  oyeebh rfeem,n
#
# tn
# wisssaurmbi  dt  wo i,tTkgtb rhtgsasiusoAbosu
# l
# k r   pe eckpcrt,
#  aine se hy
# lpu  vo,s h tmleyaiel
#
#
# o,n opur h n
# 79/79 [==============================] - 43s 544ms/step - loss: 3.0331 - val_loss: 2.8981
# Epoch 3/100
# 79/79 [==============================] - ETA: 0s - loss: 2.7268
# ----- Generating text after Epoch: 2
# ----- Generating with seed: "ined
# The clear eye’s moiety, and the dear heart’s part.
#   As thus, mine eye’s due is thy outward part,
#   And my heart’s right, thy inward love of h"
# ined
# The clear eye’s moiety, and the dear heart’s part.
#   As thus, mine eye’s due is thy outward part,
#
#
# Aoh tLoude ufeueelewftxorw’runafgynhtirimeds
#
# Mand recafeiceunforvwadhtnmdvel tgootr s,,,
#
#
# Me rhemeutetetvirepilor,,
#
#
# be thre suuu ah socbsaneshc
# 79/79 [==============================] - 45s 569ms/step - loss: 2.7268 - val_loss: 2.5120
# Epoch 4/100
# 79/79 [==============================] - ETA: 0s - loss: 2.4743
# ----- Generating text after Epoch: 3
# ----- Generating with seed: " forth the sound that said ‘I hate’,
# To me that languished for her sake:
# But when she saw my woeful state,
# Straight in her heart did mercy come,
# C"
#  forth the sound that said ‘I hate’,
# To me that languished for her sake:
# But when she saw my woeful state,
# Straight in her heart did mercy come,
#
#
# moat,ego tiisl po naridhen,
#
#
# Tirs woumlin thareares loaglt ind,?
#
#
#  Saim afd anl au
# 79/79 [==============================] - 44s 554ms/step - loss: 2.4743 - val_loss: 2.2713
# Epoch 5/100
# 79/79 [==============================] - ETA: 0s - loss: 2.3285
# ----- Generating text after Epoch: 4
# ----- Generating with seed: " art thou black save in thy deeds,
#   And thence this slander as I think proceeds.
#
#
#                     132
#
# Thine eyes I love, and they as pity"
#  art thou black save in thy deeds,
#   And thence this slander as I think proceeds.
#
#
#                     132
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#       e         1 re5
#
# 79/79 [==============================] - 44s 560ms/step - loss: 2.3285 - val_loss: 2.1683
# Epoch 6/100
# 79/79 [==============================] - ETA: 0s - loss: 2.2540
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "s an ill report.
# O what a mansion have those vices got,
# Which for their habitation chose out thee,
# Where beauty’s veil doth cover every blot,
# And "
# s an ill report.
# O what a mansion have those vices got,
# Which for their habitation chose out thee,
# Where beauty’s veil doth cover every blot,
#
#
#
#
#
#
#
#
# Bokn the M bebwr theth ther  ham ty tyafkin
# 79/79 [==============================] - 45s 564ms/step - loss: 2.2540 - val_loss: 2.0886
# Epoch 7/100
# 79/79 [==============================] - ETA: 0s - loss: 2.1967
# ----- Generating text after Epoch: 6
# ----- Generating with seed: " bear that weight in me,
# As if by some instinct the wretch did know
# His rider loved not speed being made from thee:
# The bloody spur cannot provoke "
#  bear that weight in me,
# As if by some instinct the wretch did know
# His rider loved not speed being made from thee:
#
#
#
#
#
#
#
#
#
# Folt love seerert ch st rkand’t
# 79/79 [==============================] - 44s 561ms/step - loss: 2.1967 - val_loss: 2.0374
# Epoch 8/100
# 79/79 [==============================] - ETA: 0s - loss: 2.1592
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "?
# Why with the time do I not glance aside
# To new-found methods, and to compounds strange?
# Why write I still all one, ever the same,
# And keep inven"
# ?
# Why with the time do I not glance aside
# To new-found methods, and to compounds strange?
# Why write I still all one, ever the same,
#
#
# To thene mivutt feate,hyes hy sofwe binig?
#
#
#
#
#
#
#
#
#
# Ah mowhincyisthingadeswwed, hit lopryir,
#
#
#
# Teisgwrey nothace
# 79/79 [==============================] - 44s 557ms/step - loss: 2.1592 - val_loss: 2.0275
# Epoch 9/100
# 79/79 [==============================] - ETA: 0s - loss: 2.1181
# ----- Generating text after Epoch: 8
# ----- Generating with seed: " not speed being made from thee:
# The bloody spur cannot provoke him on,
# That sometimes anger thrusts into his hide,
# Which heavily he answers with a"
#  not speed being made from thee:
# The bloody spur cannot provoke him on,
# That sometimes anger thrusts into his hide,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   f rlyelisud
# 79/79 [==============================] - 45s 564ms/step - loss: 2.1181 - val_loss: 1.9669
# Epoch 10/100
# 79/79 [==============================] - ETA: 0s - loss: 2.0840
# ----- Generating text after Epoch: 9
# ----- Generating with seed: "s, say this is not
# To put fair truth upon so foul a face?
#   In things right true my heart and eyes have erred,
#   And to this false plague are they "
# s, say this is not
# To put fair truth upon so foul a face?
#   In things right true my heart and eyes have erred,
#
#
# Leng puilo wee hade
#
#
#
#
#
#
# Hany alder for: heopnathy fufd ou then, if meverest id dacchets dal alvose daiked gav
# 79/79 [==============================] - 44s 558ms/step - loss: 2.0840 - val_loss: 1.9293
# Epoch 11/100
# 79/79 [==============================] - ETA: 0s - loss: 2.0575
# ----- Generating text after Epoch: 10
# ----- Generating with seed: " outlive long date.
#   If my slight muse do please these curious days,
#   The pain be mine, but thine shall be the praise.
#
#
#                     39"
#  outlive long date.
#   If my slight muse do please these curious days,
#   The pain be mine, but thine shall be the praise.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 79/79 [==============================] - 44s 559ms/step - loss: 2.0575 - val_loss: 1.9157
# Epoch 12/100
# 79/79 [==============================] - ETA: 0s - loss: 2.0321
# ----- Generating text after Epoch: 11
# ----- Generating with seed: " boat,
# He of tall building, and of goodly pride.
#   Then if he thrive and I be cast away,
#   The worst was this, my love was my decay.
#
#
#          "
#  boat,
# He of tall building, and of goodly pride.
#   Then if he thrive and I be cast away,
#   The worst was this, my love was my decay.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   fhy
# 79/79 [==============================] - 44s 563ms/step - loss: 2.0321 - val_loss: 1.8725
# Epoch 13/100
# 79/79 [==============================] - ETA: 0s - loss: 2.0082
# ----- Generating text after Epoch: 12
# ----- Generating with seed: "ith thee remains.
#
#
#                     75
#
# So are you to my thoughts as food to life,
# Or as sweet-seasoned showers are to the ground;
# And for "
# ith thee remains.
#
#
#                     75
#
# So are you to my thoughts as food to life,
# Or as sweet-seasoned showers are to the ground;
#
#
#
#
#
#
#
# Whins wloll great nisgeestel
# 79/79 [==============================] - 44s 557ms/step - loss: 2.0082 - val_loss: 1.8482
# Epoch 14/100
# 79/79 [==============================] - ETA: 0s - loss: 1.9841
# ----- Generating text after Epoch: 13
# ----- Generating with seed: "infant’s discontent;
# So run’st thou after that which flies from thee,
# Whilst I thy babe chase thee afar behind,
# But if thou catch thy hope turn bac"
# infant’s discontent;
# So run’st thou after that which flies from thee,
# Whilst I thy babe chase thee afar behind,
#
#
#
#
#
#
#
#
#
#
#
#
# And net ty meares il olas tir,
# 79/79 [==============================] - 44s 558ms/step - loss: 1.9841 - val_loss: 1.8358
# Epoch 15/100
# 79/79 [==============================] - ETA: 0s - loss: 1.9676
# ----- Generating text after Epoch: 14
# ----- Generating with seed: " it is an ever-fixed mark
# That looks on tempests and is never shaken;
# It is the star to every wand’ring bark,
# Whose worth’s unknown, although his h"
#  it is an ever-fixed mark
# That looks on tempests and is never shaken;
# It is the star to every wand’ring bark,
#
#
#
#
#
#
# Norminken
#
#
#
#
#
#
#
#
# Af is in thts wor
# 79/79 [==============================] - 44s 559ms/step - loss: 1.9676 - val_loss: 1.8174
# Epoch 16/100
# 79/79 [==============================] - ETA: 0s - loss: 1.9430
# ----- Generating text after Epoch: 15
# ----- Generating with seed: "shadow, since his rose is true?
# Why should he live, now nature bankrupt is,
# Beggared of blood to blush through lively veins,
# For she hath no excheq"
# shadow, since his rose is true?
# Why should he live, now nature bankrupt is,
# Beggared of blood to blush through lively veins,
#
#
#
#
#
#
#
#
#
# wetshise’starle, thou l
# 79/79 [==============================] - 44s 559ms/step - loss: 1.9430 - val_loss: 1.8034
# Epoch 17/100
# 79/79 [==============================] - ETA: 0s - loss: 1.9253
# ----- Generating text after Epoch: 16
# ----- Generating with seed: "y on the way,
# When what I seek (my weary travel’s end)
# Doth teach that case and that repose to say
# ’Thus far the miles are measured from thy friend"
# y on the way,
# When what I seek (my weary travel’s end)
# Doth teach that case and that repose to say
#
#
#
#
#
#
#
#
#
#
#   Fot l
# 79/79 [==============================] - 44s 556ms/step - loss: 1.9253 - val_loss: 1.7781
# Epoch 18/100
# 79/79 [==============================] - ETA: 0s - loss: 1.9079
# ----- Generating text after Epoch: 17
# ----- Generating with seed: "re thou hadst this more:
# Then if for my love, thou my love receivest,
# I cannot blame thee, for my love thou usest,
# But yet be blamed, if thou thy s"
# re thou hadst this more:
# Then if for my love, thou my love receivest,
# I cannot blame thee, for my love thou usest,
#
#
#
#
#
#
#
#
#
#
#
#
#
# But shav nothyy si
# 79/79 [==============================] - 44s 561ms/step - loss: 1.9079 - val_loss: 1.7649
# Epoch 19/100
# 79/79 [==============================] - ETA: 0s - loss: 1.8915
# ----- Generating text after Epoch: 18
# ----- Generating with seed: "out difference.
# Fair, kind, and true, is all my argument,
# Fair, kind, and true, varying to other words,
# And in this change is my invention spent,
# "
# out difference.
# Fair, kind, and true, is all my argument,
# Fair, kind, and true, varying to other words,
# And in this change is my invention spent,
#
#
#
#
#
#
#
#
#
#
#
#
# And hit dich abdous ell aen
# 79/79 [==============================] - 44s 555ms/step - loss: 1.8915 - val_loss: 1.7531
# Epoch 20/100
# 79/79 [==============================] - ETA: 0s - loss: 1.8753
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "r slander’s mark was ever yet the fair,
# The ornament of beauty is suspect,
# A crow that flies in heaven’s sweetest air.
# So thou be good, slander dot"
# r slander’s mark was ever yet the fair,
# The ornament of beauty is suspect,
# A crow that flies in heaven’s sweetest air.
#
#
#
#
#
#
#
#
#
# An
# 79/79 [==============================] - 44s 555ms/step - loss: 1.8753 - val_loss: 1.7471
# Epoch 21/100
# 79/79 [==============================] - ETA: 0s - loss: 1.8584
# ----- Generating text after Epoch: 20
# ----- Generating with seed: "e to be won,
# Beauteous thou art, therefore to be assailed.
# And when a woman woos, what woman’s son,
# Will sourly leave her till he have prevailed?
# "
# e to be won,
# Beauteous thou art, therefore to be assailed.
# And when a woman woos, what woman’s son,
# Will sourly leave her till he have prevailed?
#
#
#
#
#
#
#
#
# For which he pray dach eyed bas
# 79/79 [==============================] - 45s 576ms/step - loss: 1.8584 - val_loss: 1.7259
# Epoch 22/100
# 79/79 [==============================] - ETA: 0s - loss: 1.8476
# ----- Generating text after Epoch: 21
# ----- Generating with seed: "I to none alive,
# That my steeled sense or changes right or wrong.
# In so profound abysm I throw all care
# Of others’ voices, that my adder’s sense,
# "
# I to none alive,
# That my steeled sense or changes right or wrong.
# In so profound abysm I throw all care
# Of others’ voices, that my adder’s sense,
#
#
#
#
#
#
#
#
# Ce byoin bw hea
# 79/79 [==============================] - 44s 559ms/step - loss: 1.8476 - val_loss: 1.7242
# Epoch 23/100
# 79/79 [==============================] - ETA: 0s - loss: 1.8267
# ----- Generating text after Epoch: 22
# ----- Generating with seed: " This thou perceiv’st, which makes thy love more strong,
#   To love that well, which thou must leave ere long.
#
#
#                     74
#
# But be c"
#  This thou perceiv’st, which makes thy love more strong,
#   To love that well, which thou must leave ere long.
#
#
#                     74
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wonche iy ver
# 79/79 [==============================] - 45s 575ms/step - loss: 1.8267 - val_loss: 1.7037
# Epoch 24/100
# 79/79 [==============================] - ETA: 0s - loss: 1.8154
# ----- Generating text after Epoch: 23
# ----- Generating with seed: " thy store;
# Buy terms divine in selling hours of dross;
# Within be fed, without be rich no more,
#   So shall thou feed on death, that feeds on men,
# "
#  thy store;
# Buy terms divine in selling hours of dross;
# Within be fed, without be rich no more,
#   So shall thou feed on death, that feeds on men,
#
#
#
#
#
#
#
#
#
#
#
# Und the pair heth avl
# 79/79 [==============================] - 44s 560ms/step - loss: 1.8154 - val_loss: 1.6948
# Epoch 25/100
# 79/79 [==============================] - ETA: 0s - loss: 1.8026
# ----- Generating text after Epoch: 24
# ----- Generating with seed: "ainst thy reasons making no defence.
# Thou canst not (love) disgrace me half so ill,
# To set a form upon desired change,
# As I’ll my self disgrace, kn"
# ainst thy reasons making no defence.
# Thou canst not (love) disgrace me half so ill,
# To set a form upon desired change,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sowpract tha may’s bapuze, theic
# 79/79 [==============================] - 44s 560ms/step - loss: 1.8026 - val_loss: 1.6853
# Epoch 26/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7917
# ----- Generating text after Epoch: 25
# ----- Generating with seed: "thee memory,
# Thou by thy dial’s shady stealth mayst know,
# Time’s thievish progress to eternity.
# Look what thy memory cannot contain,
# Commit to the"
# thee memory,
# Thou by thy dial’s shady stealth mayst know,
# Time’s thievish progress to eternity.
# Look what thy memory cannot contain,
#
#
#
#
#
#
#
#
#
#
# The bact has noving nose
# 79/79 [==============================] - 44s 563ms/step - loss: 1.7917 - val_loss: 1.6748
# Epoch 27/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7766
# ----- Generating text after Epoch: 26
# ----- Generating with seed: " it could so preposterously be stained,
# To leave for nothing all thy sum of good:
#   For nothing this wide universe I call,
#   Save thou my rose, in "
#  it could so preposterously be stained,
# To leave for nothing all thy sum of good:
#   For nothing this wide universe I call,
#
#
#
#
#
#
#
#
#
# Notine, of by to kheved ag
# 79/79 [==============================] - 44s 562ms/step - loss: 1.7766 - val_loss: 1.6710
# Epoch 28/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7667
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "u, you pattern of all those.
#   Yet seemed it winter still, and you away,
#   As with your shadow I with these did play.
#
#
#                     99
# "
# u, you pattern of all those.
#   Yet seemed it winter still, and you away,
#   As with your shadow I with these did play.
#
#
#                     99
#
#
#
#
#
#
#
#
#
#
#
# Hos
# 79/79 [==============================] - 44s 556ms/step - loss: 1.7667 - val_loss: 1.6576
# Epoch 29/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7555
# ----- Generating text after Epoch: 28
# ----- Generating with seed: "ks me young,
# Although she knows my days are past the best,
# Simply I credit her false-speaking tongue,
# On both sides thus is simple truth suppressed"
# ks me young,
# Although she knows my days are past the best,
# Simply I credit her false-speaking tongue,
#
#
#
#
#
#
#
#
#
#
#
#
#
# Th
# 79/79 [==============================] - 45s 564ms/step - loss: 1.7555 - val_loss: 1.6530
# Epoch 30/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7415
# ----- Generating text after Epoch: 29
# ----- Generating with seed: "t is abused.
#
#
#                     83
#
# I never saw that you did painting need,
# And therefore to your fair no painting set,
# I found (or thought "
# t is abused.
#
#
#                     83
#
# I never saw that you did painting need,
# And therefore to your fair no painting set,
#
#
#
#
#
#
#
#
#
# Thee lovs loous noouse, of thin, (she
# 79/79 [==============================] - 44s 558ms/step - loss: 1.7415 - val_loss: 1.6476
# Epoch 31/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7260
# ----- Generating text after Epoch: 30
# ----- Generating with seed: " hold,
# Nor need I tallies thy dear love to score,
# Therefore to give them from me was I bold,
# To trust those tables that receive thee more:
#   To ke"
#  hold,
# Nor need I tallies thy dear love to score,
# Therefore to give them from me was I bold,
# To trust those tables that receive thee more:
#
#
#
#
#
#
#
#
#
#
#
# To wat the truen, wrenes broon te anded pr
# 79/79 [==============================] - 44s 558ms/step - loss: 1.7260 - val_loss: 1.6372
# Epoch 32/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7168
# ----- Generating text after Epoch: 31
# ----- Generating with seed: "                    18
#
# Shall I compare thee to a summer’s day?
# Thou art more lovely and more temperate:
# Rough winds do shake the darling buds of "
#                     18
#
# Shall I compare thee to a summer’s day?
# Thou art more lovely and more temperate:
#
#
#
#
#
#
#
#
#
#
#
#
#
# And I bal of hos m
# 79/79 [==============================] - 45s 564ms/step - loss: 1.7168 - val_loss: 1.6346
# Epoch 33/100
# 79/79 [==============================] - ETA: 0s - loss: 1.7059
# ----- Generating text after Epoch: 32
# ----- Generating with seed: " all her fading sweets:
# But I forbid thee one most heinous crime,
# O carve not with thy hours my love’s fair brow,
# Nor draw no lines there with thin"
#  all her fading sweets:
# But I forbid thee one most heinous crime,
# O carve not with thy hours my love’s fair brow,
#
#
#
#
#
#
#
#
#
#
#
#
#
# That  frem thou tha
# 79/79 [==============================] - 44s 556ms/step - loss: 1.7059 - val_loss: 1.6280
# Epoch 34/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6970
# ----- Generating text after Epoch: 33
# ----- Generating with seed: "mble as the proudest sail doth bear,
# My saucy bark (inferior far to his)
# On your broad main doth wilfully appear.
# Your shallowest help will hold me"
# mble as the proudest sail doth bear,
# My saucy bark (inferior far to his)
# On your broad main doth wilfully appear.
#
#
#
#
#
#
#
#
# But who whit
# 79/79 [==============================] - 44s 557ms/step - loss: 1.6970 - val_loss: 1.6263
# Epoch 35/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6853
# ----- Generating text after Epoch: 34
# ----- Generating with seed: "at record could with a backward look,
# Even of five hundred courses of the sun,
# Show me your image in some antique book,
# Since mind at first in char"
# at record could with a backward look,
# Even of five hundred courses of the sun,
# Show me your image in some antique book,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 79/79 [==============================] - 44s 562ms/step - loss: 1.6853 - val_loss: 1.6255
# Epoch 36/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6703
# ----- Generating text after Epoch: 35
# ----- Generating with seed: "mine own desert,
# And hang more praise upon deceased I,
# Than niggard truth would willingly impart:
# O lest your true love may seem false in this,
# Th"
# mine own desert,
# And hang more praise upon deceased I,
# Than niggard truth would willingly impart:
# O lest your true love may seem false in this,
#
#
#
#
#
#
#
#
# Saves cave time, mast’s facc
# 79/79 [==============================] - 44s 559ms/step - loss: 1.6703 - val_loss: 1.6195
# Epoch 37/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6615
# ----- Generating text after Epoch: 36
# ----- Generating with seed: "ion in the rose,
# They were but sweet, but figures of delight:
# Drawn after you, you pattern of all those.
#   Yet seemed it winter still, and you away"
# ion in the rose,
# They were but sweet, but figures of delight:
# Drawn after you, you pattern of all those.
#
#
#
#
#
#
#
#
#
#
# Muking do fan
# 79/79 [==============================] - 44s 559ms/step - loss: 1.6615 - val_loss: 1.6137
# Epoch 38/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6511
# ----- Generating text after Epoch: 37
# ----- Generating with seed: "ill, to you it doth belong,
# Your self to pardon of self-doing crime.
#   I am to wait, though waiting so be hell,
#   Not blame your pleasure be it ill"
# ill, to you it doth belong,
# Your self to pardon of self-doing crime.
#   I am to wait, though waiting so be hell,
#
#
#
#
#
#
#
#
#
# As seest my mike p
# 79/79 [==============================] - 44s 561ms/step - loss: 1.6511 - val_loss: 1.6174
# Epoch 39/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6399
# ----- Generating text after Epoch: 38
# ----- Generating with seed: "what good turns eyes for eyes have done,
# Mine eyes have drawn thy shape, and thine for me
# Are windows to my breast, where-through the sun
# Delights "
# what good turns eyes for eyes have done,
# Mine eyes have drawn thy shape, and thine for me
# Are windows to my breast, where-through the sun
#
#
#
#
#
#
#
#
#
#
#
#
# Hewkneld thy sore doth
# 79/79 [==============================] - 44s 557ms/step - loss: 1.6399 - val_loss: 1.6067
# Epoch 40/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6307
# ----- Generating text after Epoch: 39
# ----- Generating with seed: "ine in selling hours of dross;
# Within be fed, without be rich no more,
#   So shall thou feed on death, that feeds on men,
#   And death once dead, the"
# ine in selling hours of dross;
# Within be fed, without be rich no more,
#   So shall thou feed on death, that feeds on men,
#
#
#
#
#
#
#
#
#
# Mike mine orte
# 79/79 [==============================] - 45s 567ms/step - loss: 1.6307 - val_loss: 1.6060
# Epoch 41/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6242
# ----- Generating text after Epoch: 40
# ----- Generating with seed: " profit thee, and much enrich thy book.
#
#
#                     78
#
# So oft have I invoked thee for my muse,
# And found such fair assistance in my v"
#  profit thee, and much enrich thy book.
#
#
#                     78
#
# So oft have I invoked thee for my muse,
#
#
#
#
#
#
#
#
#
# List stall tome in the smow
# 79/79 [==============================] - 45s 575ms/step - loss: 1.6242 - val_loss: 1.6077
# Epoch 42/100
# 79/79 [==============================] - ETA: 0s - loss: 1.6108
# ----- Generating text after Epoch: 41
# ----- Generating with seed: " I then did feel,
# Needs must I under my transgression bow,
# Unless my nerves were brass or hammered steel.
# For if you were by my unkindness shaken
# "
#  I then did feel,
# Needs must I under my transgression bow,
# Unless my nerves were brass or hammered steel.
# For if you were by my unkindness shaken
#
#
#
#
#
#
#
#
#
#
#
#
#   To teel to sume, bere lar s
# 79/79 [==============================] - 44s 563ms/step - loss: 1.6108 - val_loss: 1.6034
# Epoch 43/100
# 79/79 [==============================] - ETA: 0s - loss: 1.5986
# ----- Generating text after Epoch: 42
# ----- Generating with seed: " time your own dear-purchased right,
# That I have hoisted sail to all the winds
# Which should transport me farthest from your sight.
# Book both my wil"
#  time your own dear-purchased right,
# That I have hoisted sail to all the winds
# Which should transport me farthest from your sight.
#
#
#
#
#
#
#
#
#
#   But caint’s you kand
# 79/79 [==============================] - 44s 563ms/step - loss: 1.5986 - val_loss: 1.6050
# Epoch 44/100
# 79/79 [==============================] - ETA: 0s - loss: 1.5885
# ----- Generating text after Epoch: 43
# ----- Generating with seed: "th worship thy defect,
# Commanded by the motion of thine eyes?
#   But love hate on for now I know thy mind,
#   Those that can see thou lov’st, and I a"
# th worship thy defect,
# Commanded by the motion of thine eyes?
#   But love hate on for now I know thy mind,
#
#
#
#
#
#
#
#
#
#
# Yet
# 79/79 [==============================] - 45s 567ms/step - loss: 1.5885 - val_loss: 1.6039
# Epoch 45/100
# 79/79 [==============================] - ETA: 0s - loss: 1.5835
# ----- Generating text after Epoch: 44
# ----- Generating with seed: "non
# Doubting the filching age will steal his treasure,
# Now counting best to be with you alone,
# Then bettered that the world may see my pleasure,
# S"
# non
# Doubting the filching age will steal his treasure,
# Now counting best to be with you alone,
# Then bettered that the world may see my pleasure,
#
#
#
#
#
#
#
#
# Is suv never that sourdst so-m
# 79/79 [==============================] - 44s 562ms/step - loss: 1.5835 - val_loss: 1.5984
# Epoch 46/100
# 79/79 [==============================] - ETA: 0s - loss: 1.5711
# ----- Generating text after Epoch: 45
# ----- Generating with seed: " scythe to mow.
#   And yet to times in hope, my verse shall stand
#   Praising thy worth, despite his cruel hand.
#
#
#                     61
#
# Is it "
#  scythe to mow.
#   And yet to times in hope, my verse shall stand
#   Praising thy worth, despite his cruel hand.
#
#
#                     61
#
#
#
#
#
#
#
#
#
# He fromfthese blasure of all m
# 79/79 [==============================] - 45s 565ms/step - loss: 1.5711 - val_loss: 1.5996
# Epoch 47/100
# 79/79 [==============================] - ETA: 0s - loss: 1.5620
# ----- Generating text after Epoch: 46
# ----- Generating with seed: "e thy lips to kiss.
#
#
#                     129
#
# Th’ expense of spirit in a waste of shame
# Is lust in action, and till action, lust
# Is perjured, "
# e thy lips to kiss.
#
#
#                     129
#
# Th’ expense of spirit in a waste of shame
# Is lust in action, and till action, lust
#
#
#
#
#
#
#
#
#
#
#
#
# 79/79 [==============================] - 44s 560ms/step - loss: 1.5620 - val_loss: 1.5970
# Epoch 48/100
# 79/79 [==============================] - ETA: 0s - loss: 1.5511
# ----- Generating text after Epoch: 47
# ----- Generating with seed: "ns know.
# For if I should despair I should grow mad,
# And in my madness might speak ill of thee,
# Now this ill-wresting world is grown so bad,
# Mad sl"
# ns know.
# For if I should despair I should grow mad,
# And in my madness might speak ill of thee,
# Now this ill-wresting world is grown so bad,
#
#
#
#
#
#
#
#
#
#
#
#
# Slece bare he
# 79/79 [==============================] - 44s 559ms/step - loss: 1.5511 - val_loss: 1.6077
# Epoch 49/100
# 79/79 [==============================] - ETA: 0s - loss: 1.5453
# ----- Generating text after Epoch: 48
# ----- Generating with seed: " hasten to their end,
# Each changing place with that which goes before,
# In sequent toil all forwards do contend.
# Nativity once in the main of light,"
#  hasten to their end,
# Each changing place with that which goes before,
# In sequent toil all forwards do contend.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Then same be
# 79/79 [==============================] - 45s 564ms/step - loss: 1.5453 - val_loss: 1.6058

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
